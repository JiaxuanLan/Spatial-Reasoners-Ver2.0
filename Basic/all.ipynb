# %% [markdown]
# # DS-GA 1011: More data and training: an improved baseline for Language Models as Unreliable Spatial Reasoners

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Thu Nov 17 17:33:01 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   52C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime

# %%
# connect drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/My Drive/spatialQA-main/
# %ls
# Out:
# /content/drive/My Drive/spatialQA-main
#  analysis/                                               requirements.txt
#  data.tsv                                                results/
#  figures/                                                scripts/
# 'Greene setup notes.md'                                  src/
# 'Language Models are Unreliable Spatial Reasoners.pdf'   summary/
#  README.md

# %%
# !pip install transformers
# !pip install openai
# !pip install sentencepiece

# %%
# !python scripts/generate.py

# %%
# !python scripts/test.py t5-small
# !python scripts/test.py t5-large
# !python scripts/test.py t5-base
# !python scripts/analyze.py t5-small
# !python scripts/analyze.py t5-base
# !python scripts/analyze.py t5-large

# %%
# !python scripts/test.py microsoft/deberta-base-mnli
# !python scripts/analyze.py microsoft/deberta-base-mnli

# %%
# !python scripts/test.py microsoft/deberta-large-mnli
# !python scripts/analyze.py microsoft/deberta-large-mnli

# %%
# !python scripts/test.py allenai/unifiedqa-v2-t5-small-1363200
# !python scripts/analyze.py allenai/unifiedqa-v2-t5-small-1363200

# %%
# !python scripts/test.py allenai/unifiedqa-v2-t5-large-1363200
# !python scripts/analyze.py allenai/unifiedqa-v2-t5-large-1363200

# %%
# !python scripts/test.py allenai/unifiedqa-v2-t5-base-1363200
# !python scripts/analyze.py allenai/unifiedqa-v2-t5-base-1363200

# %%
# !python scripts/test.py roberta-large-mnli
# !python scripts/analyze.py roberta-large-mnli

# %%
# !python scripts/test.py anirudh21/albert-large-v2-finetuned-mnli
# !python scripts/analyze.py anirudh21/albert-large-v2-finetuned-mnli

# %%
# !python scripts/test.py cross-encoder/nli-deberta-v3-base
# !python scripts/analyze.py cross-encoder/nli-deberta-v3-base

# %%
# !python scripts/test.py cross-encoder/nli-deberta-v3-small
# !python scripts/analyze.py cross-encoder/nli-deberta-v3-small

# %%
# !python scripts/test.py cross-encoder/nli-deberta-v3-xsmall
# !python scripts/analyze.py cross-encoder/nli-deberta-v3-xsmall

# %%
# !python scripts/test.py cross-encoder/nli-roberta-base
# !python scripts/analyze.py cross-encoder/nli-roberta-base

# %%
# !python scripts/test.py ynie/bart-large-snli_mnli_fever_anli_R1_R2_R3-nli
# !python scripts/analyze.py ynie/bart-large-snli_mnli_fever_anli_R1_R2_R3-nli

# %%
# !python scripts/test.py ynie/electra-large-discriminator-snli_mnli_fever_anli_R1_R2_R3-nli
# !python scripts/analyze.py ynie/electra-large-discriminator-snli_mnli_fever_anli_R1_R2_R3-nli

# %%
# !python scripts/test.py ynie/roberta-large-snli_mnli_fever_anli_R1_R2_R3-nli
# !python scripts/analyze.py ynie/roberta-large-snli_mnli_fever_anli_R1_R2_R3-nli

# %%
# !python scripts/test.py ynie/xlnet-large-cased-snli_mnli_fever_anli_R1_R2_R3-nli
# !python scripts/analyze.py ynie/xlnet-large-cased-snli_mnli_fever_anli_R1_R2_R3-nli

# %%
# !python scripts/test.py textattack/roberta-base-MNLI
# !python scripts/analyze.py textattack/roberta-base-MNLI

# %%
# !python scripts/test.py textattack/xlnet-base-cased-MNLI
# !python scripts/analyze.py textattack/xlnet-base-cased-MNLI
